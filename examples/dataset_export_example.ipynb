# %%
# %cd ..
# Out:
# c:\Users\almei\Documents\GitHub\research_ner_leaderboard

# %%
from spesia_ner.datasets import ClinicalRecordsDataset

dataset = ClinicalRecordsDataset('data/Spesia/argilla/annotated_records')
# Out:
# Loading all Records: 100%|██████████| 6/6 [00:01<00:00,  5.10it/s]

# %%
dataset.export(
    'ouput.jsonl',
    format="jsonl",
)
